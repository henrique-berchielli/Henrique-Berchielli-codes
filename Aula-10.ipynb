# %%
import pandas as pd

df = pd.read_excel("best-selling game consoles (2).xlsx",
                    sheet_name='consoles')

df.head
# Out:
# <bound method NDFrame.head of                          Console Name                 Type  \
# 0                       PlayStation 2                 Home
# 1                         Nintendo DS             Handheld
# 2                     Nintendo Switch               Hybrid
# 3                            Game Boy             Handheld
# 4                      Game Boy Color             Handheld
# 5                       PlayStation 4                 Home
# 6                         PlayStation                 Home
# 7                                 Wii                 Home
# 8                       PlayStation 3                 Home
# 9                            Xbox 360                 Home
# 10                   Game Boy Advance             Handheld
# 11               PlayStation Portable             Handheld
# 12                       Nintendo 3DS             Handheld
# 13                        NES/Famicom                 Home
# ...

# %%
df['Console Name'].count()
# Out:
# 51

# %%
quantidade_por_companhia = df.groupby('Company')['Console Name'].sum()


quantidade_por_companhia = quantidade_por_companhia.sort_values(ascending=False)

quantidade_por_companhia
# Out:
# Company
# Microsoft                                Xbox 360Xbox OneXboxXbox Series X/S
# Bandai                                                            WonderSwan
# Sega                       Sega Genesis/Mega DriveSega Master SystemSega ...
# Sony                       PlayStation 2PlayStation 4PlayStationPlayStati...
# Philips                                                         Philips CD-i
# NEC/Hudson Soft[note 6]                              PC Engine/TurboGrafx-16
# NEC                                                         PC Engine CD-ROM
# Nintendo                   Nintendo DSNintendo SwitchGame BoyGame Boy Col...
# Nokia                                                                 N-Gage
# Tectoy                     Master System(Brazilian variants)Mega Drive(Br...
# Magnavox/Philips                                            Magnavox Odyssey
# Mattel                                                         Intellivision
# ...

# %%
df2 = pd.read_csv('company.txt')

df2
# Out:
#                     Company  Market Value
# 0                     Atari          4160
# 1                    Bandai           913
# 2                    Coleco           767
# 3          Magnavox/Philips           693
# 4                    Mattel           548
# 5              Micro Genius           689
# 6                 Microsoft          3154
# 7                       NEC           387
# 8   NEC/Hudson Soft[note 6]           547
# 9                  Nintendo         22615
# 10                    Nokia           637
# 11                  Philips           899
# 12                     Sega         10391
# 13                     Sony          7177
# 14                   Tectoy          2538

# %%
df3 = pd.concat([df,df2])

df3
# Out:
#        Console Name      Type   Company  Released Year  Discontinuation Year  \
# 0     PlayStation 2      Home      Sony         2000.0                2013.0
# 1       Nintendo DS  Handheld  Nintendo         2004.0                2013.0
# 2   Nintendo Switch    Hybrid  Nintendo         2017.0                   0.0
# 3          Game Boy  Handheld  Nintendo         1989.0                2003.0
# 4    Game Boy Color  Handheld  Nintendo         1998.0                2003.0
# ..              ...       ...       ...            ...                   ...
# 10              NaN       NaN     Nokia            NaN                   NaN
# 11              NaN       NaN   Philips            NaN                   NaN
# 12              NaN       NaN      Sega            NaN                   NaN
# 13              NaN       NaN      Sony            NaN                   NaN
# 14              NaN       NaN    Tectoy            NaN                   NaN
#
# ...

# %%
df3['Market Value'].mean
# Out:
# <bound method Series.mean of 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#        ...
# 10      637.0
# 11      899.0
# 12    10391.0
# 13     7177.0
# 14     2538.0
# Name: Market Value, Length: 66, dtype: float64>
