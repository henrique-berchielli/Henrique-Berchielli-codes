# %%
import pandas as pd
import requests
from plyer import notification

banks_url = 'https://brasilapi.com.br/api/banks/v1'
response = requests.get(banks_url)

if response.status_code == 200:
    print('Dados importados com sucesso')
    data_json = response.json()
else: 
    print('Erro ao acessar a API')

banks_json = response.json()
df = pd.DataFrame(banks_json)

df.rename(columns={'name': 'Nome', 'fullName': 'Nome Completo' }, inplace=True)
  
df.head()

df
# Out:
# Dados importados com sucesso
#          ispb                        Nome   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    NaN
# 3    00038166                       Bacen    NaN
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                   NaN    NaN
# 358                                   NaN    NaN
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ispb           359 non-null    object
#  1   Nome           357 non-null    object
#  2   code           348 non-null    float64
#  3   Nome Completo  357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 11.3+ KB

# %%
filled_df = df.fillna(-1)
print(filled_df)

df = df.dropna()
df
# Out:
#          ispb                        Nome   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic   -1.0
# 3    00038166                       Bacen   -1.0
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                    -1   -1.0
# 358                                    -1   -1.0
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
df[df['code'] > 200]
# Out:
#          ispb                             Nome   code  \
# 4    00122327            SANTINVEST S.A. - CFI  539.0
# 5    00204963                        CCR SEARA  430.0
# 6    00250699                      AGK CC S.A.  272.0
# 8    00329598  ÍNDIGO INVESTIMENTOS DTVM LTDA.  407.0
# 12   00460065                 COLUNA S.A. DTVM  423.0
# ..        ...                              ...    ...
# 350  91884981            BANCO JOHN DEERE S.A.  217.0
# 353  92874270                BCO DIGIMAIS S.A.  654.0
# 354  92875780                 WARREN CVMC LTDA  371.0
# 355  92894922                   BANCO ORIGINAL  212.0
# 356  94968518                     EFX CC LTDA.  289.0
#
#                                          Nome Completo
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# 5      COOPERATIVA DE CREDITO RURAL SEARA - CREDISEARA
# 6                         AGK CORRETORA DE CAMBIO S.A.
# 8    ÍNDIGO INVESTIMENTOS DISTRIBUIDORA DE TÍTULOS ...
# ...

# %%
df.loc[df['code'] > 200, 'Nome']
# Out:
# 4                SANTINVEST S.A. - CFI
# 5                            CCR SEARA
# 6                          AGK CC S.A.
# 8      ÍNDIGO INVESTIMENTOS DTVM LTDA.
# 12                    COLUNA S.A. DTVM
#                     ...
# 350              BANCO JOHN DEERE S.A.
# 353                  BCO DIGIMAIS S.A.
# 354                   WARREN CVMC LTDA
# 355                     BANCO ORIGINAL
# 356                       EFX CC LTDA.
# Name: Nome, Length: 245, dtype: object

# %%
indexed_df = df.set_index(['ispb', 'Nome', 'Nome Completo'])

df_stacked = df.stack()

print(df_stacked)
print(indexed_df)
# Out:
# 0    ispb                                  00000000
#      Nome                        BCO DO BRASIL S.A.
#      code                                       1.0
#      Nome Completo             Banco do Brasil S.A.
# 1    ispb                                  00000208
#                                   ...
# 356  Nome                              EFX CC LTDA.
#      code                                     289.0
#      Nome Completo    EFX CORRETORA DE CÂMBIO LTDA.
# 357  ispb
# 358  ispb
# Length: 1421, dtype: object
#                                                                                          code
# ispb     Nome                       Nome Completo
# 00000000 BCO DO BRASIL S.A.         Banco do Brasil S.A.                                  1.0
# 00000208 BRB - BCO DE BRASILIA S.A. BRB - BANCO DE BRASILIA S.A.                         70.0
# 00038121 Selic                      Banco Central do Brasil - Selic                       NaN
# ...
